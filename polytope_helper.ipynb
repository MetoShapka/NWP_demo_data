# %% [markdown]
# # UrbanAIR Polytope fetch
#
# GUI tool to download fdb archive for UrbanAIR using polytope
#
# To use polytope put your ECMWF web API key, https://api.ecmwf.int/v1/key/ in a ~/.polytopeapirc file as
#
# {
#     "user_key"   : "some_hash",
#     "user_email" : "foo.bar@somewhere.ok"
# }
#
# ## Run:
# ***Kernel > Restart kernel and run all cells***
#
# ## Instructions:
# * Chose an archive version
# * Select a level type and paramter type, this is necessary as it as mixing level types and time-lables is difficult for polytope requests
# * Select parameters and levels when available. *shift+click* or *ctrl+click* to select mulitiple.
# * Click on `create request`, polytope request is shown in the output. *Incomplete request will show a warning, this will fail if you try to download*.
# * Select format, choose an output file path
# * Click `Download`

# %%
import pt_UI
pt_UI.main_loop()
